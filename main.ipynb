# %%
import pandas as pd
data = {
    "Name": ["Ankurl", "Abhay", "Anshul"],
    "Age": [17, 16, 15],
    "City": ["Bhopal", "Delhi", "Mumbai"]}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age    City
# 0  Ankurl   17  Bhopal
# 1   Abhay   16   Delhi
# 2  Anshul   15  Mumbai
